# %%
from matplotlib import pyplot as plt
from matplotlib import image as mpimg


def show_picture(image_path):
    image = mpimg.imread(image_path)
    plt.imshow(image, cmap='gray')
    plt.show()

import glob

def all_pictures(image_mask):
    for image in glob.glob(image_mask):
        show_picture(image)

# %%
path = "C:\\Users\\User\\jupyter\\"
show_picture(path + "ocropy_venv_p2.7\\DUP-ocropy\\book\\0001.bin.png")
all_pictures(path + "ocropy_venv_p2.7\\DUP-ocropy\\book\\0001\\*")

Для целого листа результаты есть здесь: https://github.com/gudkovst/Recognition-volost-tribunals/tree/main/example_ocropy_frag/test_2

B

# %%
show_picture(path + "ocropy_venv_p2.7\\DUP-ocropy\\book_4_reshenie\\0001.bin.png")
all_pictures(path + "ocropy_venv_p2.7\\DUP-ocropy\\book_4_reshenie\\0001\\*")

# %%
show_picture(path + "ocropy_venv_p2.7\\DUP-ocropy\\book_tibet1\\0001.bin.png")
all_pictures(path + "ocropy_venv_p2.7\\DUP-ocropy\\book_tibet1\\0001\\*")
